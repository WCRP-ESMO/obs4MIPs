# %%
# Jupyer notebook to check dimensions of netCDF data files used by REF
# Tested with the NOAA-NCEI GLODAPv.2 dataset
# PSmith 25-12-17 

#!/usr/bin/env python
"""
Check the temperature data array dimensions
"""
import xarray as xr
import xcdat as xc
import numpy as np

inputFilePath = '/obs4MIPs-cmor-tables/inputs/NOAA-NCEI/GLODAP-2-2016b/GLODAPv2.2016c.temperature.nc'
inputVarName = 'temperature'

print("="*70)
print("DATA ARRAY DIMENSION CHECK")
print("="*70)
# Out:
# ======================================================================
# DATA ARRAY DIMENSION CHECK
# ======================================================================

# %%
# Open file
f = xc.open_dataset(inputFilePath, decode_times=False)
d = f[inputVarName]

print(f"\nVariable: {inputVarName}")
print(f"Shape: {d.shape}")
print(f"Dimensions: {d.dims}")
print(f"Data type: {d.dtype}")

print(f"\nCoordinate information:")
for dim in d.dims:
    coord = f[dim]
    print(f"  {dim}: size={coord.size}, values range=[{coord.values.min():.2f}, {coord.values.max():.2f}]")

print(f"\nExpected dimension order for CMOR with axes=[olevel, lat, lon]:")
print(f"  Should be: (depth, lat, lon) = (33, 180, 360)")
print(f"  Actually is: {d.dims} = {d.shape}")

if d.dims == ('depth', 'lat', 'lon'):
    print("✓ Dimension order matches!")
elif d.dims == ('lat', 'lon', 'depth'):
    print("✗ ERROR: Dimension order is wrong! Need to transpose.")
    print("  Use: d = d.transpose('depth', 'lat', 'lon')")
else:
    print(f"✗ ERROR: Unexpected dimension order: {d.dims}")

print("\n" + "="*70)
# Out:
# Variable: temperature
# Shape: (33, 180, 360)
# Dimensions: ('depth', 'lat', 'lon')
# Data type: float64
#
# Coordinate information:
#   depth: size=33, values range=[0.00, 32.00]
#   lat: size=180, values range=[-89.50, 89.50]
#   lon: size=360, values range=[20.50, 379.50]
#
# Expected dimension order for CMOR with axes=[olevel, lat, lon]:
#   Should be: (depth, lat, lon) = (33, 180, 360)
#   Actually is: ('depth', 'lat', 'lon') = (33, 180, 360)
# ✓ Dimension order matches!
#
# ======================================================================
